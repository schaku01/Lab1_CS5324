# %% [markdown]
# # Lab (1) Solutions

# %%
# Import pandaaaa oh and matplowhafuf
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# why is this so complicated
df = pd.read_csv('archive/Speed Dating Data.csv')
# df idk what im doing
df
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0       1   1.0       0    1       1     1     10         7       NaN      4
# 1       1   1.0       0    1       1     1     10         7       NaN      3
# 2       1   1.0       0    1       1     1     10         7       NaN     10
# 3       1   1.0       0    1       1     1     10         7       NaN      5
# 4       1   1.0       0    1       1     1     10         7       NaN      7
# ...   ...   ...     ...  ...     ...   ...    ...       ...       ...    ...
# 8373  552  22.0       1   44       2    21     22        14      10.0      5
# 8374  552  22.0       1   44       2    21     22        13      10.0      4
# 8375  552  22.0       1   44       2    21     22        19      10.0     10
# 8376  552  22.0       1   44       2    21     22         3      10.0     16
# 8377  552   NaN       1   44       2    21     22         2      10.0     15
#
# ...

# %%
# can compare gender and match
df.describe()
# Out:
#                iid           id       gender          idg       condtn  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248     0.500597    17.327166     1.828837
# std     158.583367     5.491329     0.500029    10.940735     0.376673
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     154.000000     4.000000     0.000000     8.000000     2.000000
# 50%     281.000000     8.000000     1.000000    16.000000     2.000000
# 75%     407.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  ...  \
# count  8378.000000  8378.000000  8378.000000  6532.000000  8378.000000  ...
# mean     11.350919    16.872046     9.042731     9.295775     8.927668  ...
# std       5.995903     4.358458     5.514939     5.650199     5.477009  ...
# ...

# %%
df2 = df[["id", "gender", "condtn"]]
df2
# Out:
#         id  gender  condtn
# 0      1.0       0       1
# 1      1.0       0       1
# 2      1.0       0       1
# 3      1.0       0       1
# 4      1.0       0       1
# ...    ...     ...     ...
# 8373  22.0       1       2
# 8374  22.0       1       2
# 8375  22.0       1       2
# 8376  22.0       1       2
# 8377   NaN       1       2
#
# [8378 rows x 3 columns]

# %%
df2.describe()
# Out:
#                 id       gender       condtn
# count  8377.000000  8378.000000  8378.000000
# mean      8.960248     0.500597     1.828837
# std       5.491329     0.500029     0.376673
# min       1.000000     0.000000     1.000000
# 25%       4.000000     0.000000     2.000000
# 50%       8.000000     1.000000     2.000000
# 75%      13.000000     1.000000     2.000000
# max      22.000000     1.000000     2.000000

# %%
df3 = df.drop(["iid"], axis=1)
df3
# Out:
#         id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0      1.0       0    1       1     1     10         7       NaN      4
# 1      1.0       0    1       1     1     10         7       NaN      3
# 2      1.0       0    1       1     1     10         7       NaN     10
# 3      1.0       0    1       1     1     10         7       NaN      5
# 4      1.0       0    1       1     1     10         7       NaN      7
# ...    ...     ...  ...     ...   ...    ...       ...       ...    ...
# 8373  22.0       1   44       2    21     22        14      10.0      5
# 8374  22.0       1   44       2    21     22        13      10.0      4
# 8375  22.0       1   44       2    21     22        19      10.0     10
# 8376  22.0       1   44       2    21     22         3      10.0     16
# 8377   NaN       1   44       2    21     22         2      10.0     15
#
#       partner  ...  attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  \
# ...

# %%
df = df.astype({"gender": "string"})
plt.hist(df["gender"])
plt.xticks(["0","1"], ["male", "female"])
plt.show()
